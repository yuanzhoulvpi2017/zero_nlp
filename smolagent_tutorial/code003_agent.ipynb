# %%
from src.tools.web_search import BaiDuSearchTool
from smolagents import CodeAgent, GradioUI, OpenAIServerModel, stream_to_gradio

# %%
MODEL_NAME_1 = "Qwen2.5-72B-Instruct"
MODEL_NAME_2 = "model_2"


def create_agent(model_name=MODEL_NAME_1):
    """为每个新会话创建新的Agent实例"""
    search_tool = BaiDuSearchTool()

    if model_name == MODEL_NAME_1:
        model = OpenAIServerModel(
            model_id="Qwen2.5-72B-Instruct",
            api_base="http://10.136.0.65:7008/v1",
            api_key="EMPTY",
        )
    elif model_name == MODEL_NAME_2:
        model = OpenAIServerModel(
            model_id="Qwen2.5-72B-Instruct",
            api_base="http://10.136.0.65:7008/v1",
            api_key="EMPTY",
        )

    # 每次调用此函数时创建新的Agent实例
    return CodeAgent(
        tools=[search_tool, wather_tool],
        model=model,
    )

agent1 = create_agent(MODEL_NAME_1)

# %%
answer = agent1.run("尼康z63的参数怎么样")
answer
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 尼康z63的参数怎么样                                                                                             │
# │                                                                                                                 │
# ╰─ OpenAIServerModel - Qwen2.5-72B-Instruct ──────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   result = baidu_search(query="尼康z63参数")
#   print(result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [尼康Z6 III(数码相机) -
# 百度百科](http://www.baidu.com/link?url=6YeL0b1GS5YrmhHU6gP2Hx7YGwixi0tmxgx59EzA7ybKgtLJadZoSS_zM0EyYrBpC1ypvEIDb4N
# S2YDcYCUunXI3aYssOGLGym4t7aMnSTK)
# 发布时间: 未找到日期
#  网页新闻贴吧知道网盘图片视频地图文库资讯采购百科
# 百度首页
# 登录
# 注册
# 进入词条
# 全站搜索
# 帮助
# 首页
# 秒懂百科
# 特色百科
# 知识专题
# 加入百科
# 百科团队
# 权威合作
# 个人中心
# 收藏
# 0
# 0
# 尼康Z6 III
# 播报
# 编辑
# 讨论
# 上传视频
# 数码相机
# 尼康Z6 III是尼康推出的新一代全画幅微单数码相机。 [1-3]
# 相关星图
# 尼康Z系列相机
# 共13个词条4692阅读
# 尼康 Z5Ⅱ
# 尼康 Z5Ⅱ是尼康发布的全画幅相机。2025年4月3日，尼康 Z5 Ⅱ 相机新品正式发布，市场参考价 10999
# 元，将于4月24日开售。尼康
# Z5Ⅱ的尺寸（宽×高×厚）约为144mm×103mm×49mm，机身重量（含电池和存储卡）约为700克。Z5II搭载全画幅背照式CMOS传感器，结
# 合EXPEED
# 7影像处理器。其传承自旗舰机型的自动对焦性能，支持9种对象侦测和3D追踪，更精准地掌控影像创作。Z5II还配备专门的优化校
# 准按钮，并支持色彩方案等创新工具，让创意更加自由。强大的减震系统在画面中心可提供高达约7.5档、画面边缘约6档的补偿效
# 果，即使在较慢的快门速度下，也能使画面清晰稳定。此外，其自动对焦在低至-10EV的昏暗环境中依然可靠，而高感光度性能在照
# 片拍摄时可达ISO 64000，视频拍摄时可达ISO
# 51200，在低光环境下依然能呈现出色的影像质量和噪点控制表现。尼康将在满足用户需求的同时，继续追求光学性能的新维度，旨
# 在进一步扩大影像表现的可能性，为影像文化的发展做出贡献。
# 尼康Z 5
# 尼康Z 5（英语：Nikon Z 5）是尼康于2020年7月推出的一款全画幅微单数码相机。相机定位和售价低于尼康Z
# 6。相机使用了具有约2430万有效像素的全画幅CMOS图像传感器，Expeed 6图像处理器，支持ISO 100至ISO
# 51200感光度，并在机身内支持五轴防抖；相机的对焦系统采用了和尼康Z
# 6相同的273对焦点复合自动对焦系统，支持人眼和动物检测；视频方面，相机支持在约1.7倍裁切下的4K分辨率视频录制；相机提供
# 双SD卡存储卡槽。
# 尼康Z 30
# 尼康Z30是尼康于2022年6月发布的一款APS-C画幅微单数码相机(微单相机)。采用了尼康DX格式影像传感器，EXPEED
# 6影像处理器和尼克尔Z卡口镜头的组合。机身小巧轻便，拥有眼睛侦测自动对焦（AF）功能(支持在视频和照片中清晰对焦于眼睛)
# ；可翻转显示屏支持轻松自拍和探索更多创意角度；长达约125分钟的视频录制；针对视频录制进行优化，是内容创作的理想之选；
# 支持4K超高清视频录制和创意优化校准扩展创意的可能性；兼容对内容创作者友好的应用程序和软件。
# 尼康Z 50
# 尼康Z 50（Nikon Z
# 50）是日本尼康公司于2019年发布的一款紧凑型数码无反光镜可换镜头相机。产品于2019年11月22日正式在中国大陆地区上市销售
# 。
# 中文名
# 尼康Z6 III
# 上市时间
# 2024年6月17日
# 所属品牌
# 尼康
# 目录
# 1发展历史
# 2功能配置
# 发展历史
# 播报
# 编辑
# 尼康Z6 III于2024年6月17日正式发布，售价 2500 美元。 [4]
# 功能配置
# 播报
# 编辑
# ·搭载新型2450万像素BSI背照式CMOS
# · 搭载新的影像处理器（EXPEED 7）
# · 有出色的低光画质表现和高动态范围
# · 快门速度至高达1/16000秒
# · 至高连拍速度机械快门14fps、电子快门20fps（14bit RAW）
# 尼康 Z6 III
# (2张)
# · 至高连拍速度120fps（JPEG）
# · 293 / 297点自动对焦点
# · 自动对焦点画面覆盖率将近100%
# · 更新了自动对焦算法
# · 至高可录制6K 12bit NRAW（无裁切）
# · 支持4K 60P ProRes RAW录制
# · 支持FHD 240P高格率录制（裁切）
# · 至高可连续视频拍摄120分钟
# · 五轴7级或8级机身防抖
# · 全新576万像素EVF电子取景器
# · 改良的翻转屏幕支持像素位移拍摄
# · CFexpress + SD双卡槽
# · 手柄和按钮布局大致上与Z8相似
# · 机身重量较Z6 II重30-40%
# · 机身重量约700-750g
# · USB-C 3.0、HDMI A
# · 全新散热设计
# · 支持Z6 III的Nikon NX Studio新版本App即将发布 [1]
# 词条图册
# 更多图册
# 概述图册
# (1张)
# 尼康 Z6 III
# (2张)
# 参考资料
# 1苦等四年！尼康Z6 III正式官宣：变革拍摄方式．百家号-快科技 [引用日期2024-06-10]
# 2号称“按下快门前就能定格画面”，尼康 Z6 III 6 月 17 日发布．百家号．2024-06-17
# 3尼康 Z6 III 相机发布：搭载 24.5MP 传感器、EVF 亮度 4000 尼特，国行 18999 元．IT之家 [引用日期2024-06-17]
# 4尼康 Z6 III 相机发布：24.5MP、EVF 亮度 4000 尼特，2500 美元． IT之家．2024-06-17
# 尼康Z6 III的概述图（1张）
# 词条统计
# 浏览次数：19473次
# 编辑次数：4次历史版本
# 最近更新：
# 瑾年落2
# （2024-06-17）
# 突出贡献榜
# 瑾年落2
# 怀念me艾迪
# 乡人原是客
# bschoolk
# 相关搜索
# 游戏培训机构
# 清洗管道疏通
# 脸上有轻微白块怎么办
# 蓝月传奇官网
# 飞牛
# 少儿模特加盟培训班
# 主要检查些什么项目
# 新手上路
# 成长任务
# 编辑入门
# 编辑规则
# 本人编辑
# 我有疑问
# 内容质疑
# 在线客服
# 官方贴吧
# 意见反馈
# 投诉建议
# 举报不良信息
# 未通过词条申诉
# 投诉侵权信息
# 封禁查询与解封
# ©2025 Baidu 使用百度前必读 | 百科协议 | 隐私政策 | 百度百科合作平台 | 京ICP证030173号
# 京公网安备11000002000001号
#
# [【尼康Z6III】报价_参数_图片_论坛_Nikon Z6
# 3,Z63尼康数码相机...](http://www.baidu.com/link?url=KU7_tTyrdoKI8HOeF9EZNP6eUDNDzgMa80CFviviFrbA0S1313YRXS70U8uNPK8
# aFR5uYd_HnCU91uUaSx3yjGovwUCRCqEguJiAQuvzZRO)
# 发布时间: 未找到日期
#  登录
# 中关村在线
# 网站导航
# 产品排行
# 产品入库
# 广告联盟
# 手机客户端
# ZOL产品报价
# |
# 数码相机
# 全部分类
# 排行榜
# 新品
# 一拍即合
# ZOL报价首页
# >
# 数码相机
# >
# 尼康数码相机
# >
# 尼康Z6III
# 24 尼康Z6III[系列共2款]别名：Z6 3，Z63
# 4K120P，体育摄影，2400万像素全画幅传感器
# 综述介绍
# 参数
# 图片(58)
# 视频(9)
# 点评(303)
# 比价
# 竞品对比
# 评测行情
# 论坛
# 问答
# 更多
# 03′25″
# 播放视频
# 评测图解
# 评测图解
# 共58张图片>>
# 参考报价：
# ￥18999
# 京东 ¥14699
# 淘宝 ¥14969
# 商家报价：
# 价格面议（本地3家经销商）
# 力荐
# 10.0
# 303人评分
# 热帖|品牌排行榜第2名
# 性价比：7.2 操作：10 电池：7.2 屏幕：10 成像：10 做工：10
# 评测
# 几秒就搞定色彩方案 尼康云创到底好不好用？
# 行情
# 尼康 Z6 III 全画幅微单相机限时特惠
# ¥14699
# 去逛逛
# 加入对比
# 配置参数
# 详细参数
# 传感器：全画幅（35.9*23.9mm）
# 有效像素：2450万
# 显示屏尺寸：3.2英寸
# 显示屏像素：210万像素液晶屏
# 连拍速度：支持（最高约14张/秒）
# 快门速度：1/8000至30 秒（以1/3、1/2或1EV为增....>>
# 电池类型：锂电池（1块EN-EL15c锂离子电池组）
# 续航能力：暂无数据
# 查看完整参数>>
# 尼康相机最新价格15726619297
# 产品图解
# 更多图片>>
#   购机必读
# 尼康 Z6 III 全画幅微单相机限时特惠
# 尼康 Z6 III 全画幅微单相机 黑色
# 单机身，搭载高性能传感器与强劲影像处理系统，支持高速连拍、精准对焦与出色的视频拍摄能力，轻巧便携的设计适合专业摄影
# 师及摄影爱好者日常创作与旅行记录。目前参与补贴活动，原价18999元 [阅读全文]
# 2025-05-24 12:19:57
# 尼康Z6 III全画幅微单相机限时特惠17699元
# 尼康 Z6 III 全画幅微单相机 黑色
# 单机身正在天猫商城热销中，原价22499元，现叠加多重优惠后到手价仅需17699元。本次促销可领取满15000元减2800元优惠券，并
# 享受国家补贴8.5折起（减2000元），性价比大幅提升。作为一款备受期 [阅读全文]
# 2025-05-22 14:21:17
# 尼康 Z8
# 尼康Z6III，近日在商家“路美科技”特价促销，优惠价为17999元，好物好价，值得您入手！尼康Z6III产品亮点为4K120P，体育摄影
# ，2400万像素全画幅传感器。感兴趣的朋友可直接前往北京市海淀区科贸电子城详询，关于尼康Z6III的 [阅读全文]
# 2025-04-19 13:59:21
# 尼康 Z6III
# 尼康Z6III数码相机，近日在商家路美科技特价促销，优惠价为13599元，好物好价，值得您入手！产品亮点为4K120P，体育摄影，2
# 400万像素全画幅传感器。感兴趣的朋友可直接前往北京市海淀区科贸电子城详询，关于尼康Z6III数码相 [阅读全文]
# 2025-04-12 10:03:59
# 尼康Z6 III微单京东活动价14475元
# 尼康Z6
# III全画幅微单相机是摄影爱好者的得力助手。它作为微单套机，在高清摄影、拍照、视频直播以及拍摄vlog方面表现卓越。其能精
# 准捕捉精彩瞬间，为画面提供高清的画质输出，无论是拍摄风景、人物还是记录生活中的有趣时刻都 [阅读全文]
# 2025-04-01 22:15:04
# 大家来点评
# 303条口碑评论
# 我要点评
# 10.0
# 303人评分
# 7.2
# 性价比
# 10
# 操作
# 7.2
# 电池
# 10
# 屏幕
# 10
# 成像
# 10
# 做工
# 大家都说：
# 性能优秀(1)
# d1vm32
# 购买信息
# 时间：2024-10
# 地点：北京
# 操控性能不错，对焦系统强大，显示屏不错户外看屏幕也很清晰
# 8.8
# 做工：10成像：10屏幕：10电池：6操作：10性价比：6
# 优点：
# 操控性能不错，对焦系统强大，显示屏不错户外看屏幕也很清晰
# 缺点：
# 没性价比可以，电池草鸡不耐用，翻转屏不然z8z9的折叠屏好用，有几个会用相机自拍的，手机自拍不香吗？搞成翻转屏是怎么想
# 的，体验了下决定不买，还是用回z9香
# 发表于：2024-10-12
# 赞
# 评论
# 1j80z6
# 10.0
# lgy181091腾龙公司的开户与注册流程可以根据不同的方式进行，以下是几种常见的注册开户流程概述：在线注册：通过腾龙公司的
# 官方网站或移动端应用进行注册。首先需要填写基本信息（如姓名、手机号码、电子邮箱等），提交验证码后完成注册过程。之后
# 完善个人信息，包括但不限于姓名、性别、出生年月等，以便使用腾龙人工注册：可以通过腾龙公司的客服电话或在线客服进行，
# 客服人员会协助完成整个注册流程开户流
# 发表于：2024-10-27
# 赞
# 评论
# j***4
# 10.0
# 相机性能卓越，画质细腻，对焦迅速，操作流畅，值得拥有。
# 发表于：2025-02-25
# 赞
# 评论
# 查看全部点评>>
# 电商优惠推荐
# 尼康Z8
# 京东 ￥2.3万
# 尼康D780
# 京东 ￥9999
# 佳能EOS 90D
# 京东 ￥6599
# 索尼ZV-E10
# 京东 ￥5245
# 索尼ZV-E10L套机 (16-50mm)
# 京东 ￥4788
# 接下来要看
# 数码相机
# 尼康数码相机
# 手机上浏览
# 用户还关注
# 同价位
# 同品牌
# 1
# 佳能EOS R5 Mark II（单机身）
# 对比
# ￥26999
# 2
# 佳能EOS R6 Mark II
# ￥17999
# 3
# 索尼Alpha 1 II
# ￥47999
# 4
# 索尼A7 IV
# ￥19960
# 5
# 佳能5D Mark IV(单机)
# ￥16799
# 6
# 富士GFX100 II单机身
# ￥53900
# 中关村在线提示您，购买前请和商家确认清楚商品版本型号。【广告】
# 杭州
# 北京
# 华晨数码(渠道批发)
# ￥15740
# 010-82539071
# qq交谈
#
#
# 路美科技
# ￥15740
# 18310578090
# qq交谈
#
#
# 北京数码商城(渠道批发)
# ￥17225
# 13051300575
# qq交谈
#
#
# 热门对比产品推荐
# 1
# 佳能EOS R6 Mark II
# 对比
# ￥17999
# 2
# 佳能EOS R5
# ￥25999
# 3
# 尼康Z8
# ￥27999
# 4
# 索尼A7 IV
# ￥19960
# 5
# 尼康Z7II(单机)
# ￥19799
# 6
# 哈苏X2D 100C
# ￥54900
# 7
# 尼康Z9
# ￥35999
# 8
# 尼康Z f
# ￥15299
# 9
# 富士GFX100 II单机身
# ￥53900
# 10
# 索尼A7RⅤ
# ￥25999
# 关注该品牌的还关注
# 换一换
# ￥10999
# 尼康Z5II
# 同品牌，同产品类型
# 好评率100%
# 对比
# ￥6199
# 尼康Z50II
# 同品牌，同产品类型
# 好评率100%
# 对比
# ￥9099
# 尼康Z5
# 同品牌，同产品类型
# 好评率99%
# 对比
# ￥13799
# 尼康Z6II(单机)
# 同品牌，同产品类型
# 好评率100%
# 对比
# 本月新品
# 6月
# 富士 X-HF1
# 参考报价：价格面议
# 4月
# 尼康 Z5II
# 4月
# 佳能 PowerShot V1
# 2月
# 尼康 P1100
# 12月
# 索尼 Alpha 1 II
# 大家都买什么
# 同价位
# 同品牌
# 1
# 佳能EOS R5 Mark II（单机身）
# 对比
# ￥26999
# 2
# 佳能EOS R6 Mark II
# ￥17999
# 3
# 索尼Alpha 1 II
# ￥47999
# 4
# 索尼A7 IV
# ￥19960
# 5
# 佳能5D Mark IV(单机)
# ￥16799
# 6
# 富士GFX100 II单机身
# ￥53900
# 7
# 富士GFX100RF
# ￥34900
# 8
# 索尼A7RⅤ
# ￥25999
# 9
# 富士X-H2S
# ￥16700
# 10
# 尼康Z6III
# ￥18999
# 口碑排行
# 品牌排行
# 热度排行
# 大家都在看
# 热门
# 新品
# 1
# 尼康Z5II
# 对比
# ￥10999
# 2
# 尼康Z50II
# ￥6199
# 3
# 尼康Z5
# ￥9099
# 4
# 尼康Z6II(单机)
# ￥13799
# 5
# 尼康Z6III
# ￥18999
# 6
# 尼康Z7II(单机)
# ￥19799
# 7
# 尼康Z9
# ￥35999
# 8
# 尼康Z 30
# ￥4799
# 9
# 尼康Z8
# ￥27999
# 10
# 尼康Z fc（单机）
# ￥6499
# 热门标签
# 按产品
# 换一换
# 手机
# 导航仪
# 空气净化器
# 抽油烟机
# 电饭煲
# 电吹风
# 音频播放器
# 笔记本电脑
# 电烧烤炉
# 中央空气净化器
# 相关配件
# 镜头
# 闪存卡
# 读卡器
# 相机贴膜
# 相机电池
# 取景器
# 单反手柄
# 对焦屏
# 相机包
# 相机配件
# 清洁养护
# 转接环/筒
# 镜头盖
# 综述介绍
# 参数
# 图片(58)
# 视频(9)
# 点评(303)
# 比价
# 竞品对比
# 评测行情
# 论坛
# 问答
# 更多
# 公司简介|公司历程|营销推广|媒体合作|品牌大全|帐号注册|招聘信息|联系方式|隐私声明|站点地图|反馈纠错
#  ©2025 中关村在线 版权所有
#
# [用了一段时间尼康Z63,这些是我想和你说的!](http://www.baidu.com/link?url=Ldcwp-YpUMqYFoNSFaF4AD2KQNsBcApgUpMlEbIiFT1
# PUjZ7efKaWx_G-hB5kkEoZb2pmSyWS3k-RQavI6IC3tSDe9krBP9z613T_g7dYyy)
# 发布时间: 2024年8月18日
#  百度首页
# 用了一段时间尼康Z63，这些是我想和你说的！
# 南向科技
# 2024-08-18 19:10
# 福建
# 距离尼康Z63发布已经接近2个月了，作为尼康Z6系列的第三代，这一次的尼康Z63将升级重点放在了视频领域，首款部分堆栈传感器
# 的加入，理论上确实让尼康Z63的整体性能得到不小的提升，但首发18999元的价格却又让很多用户喊出“尼康药丸”，那么这台尼康Z
# 63的综合性能究竟如何？
# 带着好奇，趁着要准备尼康夏会，我也用了一段时间尼康Z63，简单谈谈我对这台尼康相机的使用感受。
# 实用的改进
# 外观方面，这次尼康Z63整体机身要比尼康Z6更厚一些，肩屏面积也更大了，可以显示的内容也更多一些，另外也配备了背光空间按
# 钮。
# Logo分布也和之前不一样，正面并没有保留尼康Z63的log而是只保留了”Z“符号。
# 将Z63的身份识别放到了机身顶部。
# 拨轮按钮和Z6变化不大，如果之前有用过尼康的相机会很熟悉按键布局。
# 这次尼康Z63终于用上了210万点3.2英寸的翻转屏幕，拍摄视频来说确实更加友好，以前我用尼康Z6或者Z8拍摄自己说活的画面（Ar
# oll）都要加一台监看设备，有了翻转屏就可以直接监看到实时画面。
# 并且显示屏也是支持竖向显示，拍摄竖屏内容也可以很方便的查看参数。
# 相比起显示屏，这次OLED电子取景器的提升更加显著，其拥有约576万像素，并具有宽广的DCI-P3色域，亮度可达4000cd/m²。整体
# 观感确实好上不少，拍摄风景的时候透过这块OLED取景器有种超现实的观感，当然如果要准确曝光，建议大家还是打开波形图。
# 不过虽然电子取景器非常出色，但这段时间使用下来，我依然更习惯用显示器取景。
# 卡槽方面这次尼康依旧是采用了1张CFexpress Type
# B或XQD存储卡和1张SD存储卡的存储方案，这是我认为目前最合理也最实用的存储方案。
# 电池依旧是EN-EL15c，续航很不错，轻度拍摄一颗电池就够用一天了。并且之前尼康的电池也都可以继续使用，这点确实要给尼康
# 点赞。
# 机身的左侧接口这次进步很大，首先是采用线性输入接口，这可以帮助更好保留高品质音频，另外全尺寸的HDMI终于来到了Z6系列
# 相机上。
# 我之前用的Z6相机，只支持mini
# HDMI，如果临时有直播需求，有没有带线材就很尴尬，这次换上了全尺寸的HDMI确实普适性更好，而且接口更大也相比起来更加牢
# 固可靠。
# CMOS够用吗
# 在尼康发布前包括我在内都在猜测尼康Z63这次会不会提升像素，毕竟隔壁家的水桶机已经用上了3300w像素，但这次尼康Z63的像素
# 依旧是2450万。
# 很多人就会发问“手机都一亿像素了，相机2450万像素够用吗？”答案是“够”。无论是城市风光还是人像人文都足够使用了，并且245
# 0万像素带来的存储压力也不会非常大。
# 新的CMOS也让读取速度更快，拥有了高达120幅/秒的预拍功能。如果在FX格式60幅/秒模式下，也可以以约2400万有效像素进行捕捉
# ，这甚至高于Z9的60幅/秒模式的分辨率。
# 所以我觉的这个像素还是非常甜点的。算是目前在这个价位段比较兼顾拍照和视频的像素，所带来的整体画质也是很不错的。
# 尼康Z63+Z24-120mmF/4s
# 当然如果热爱裁切二次构图，尼康Z63也可以合成最高9600万像素的照片。我
# 当然相比起拍照来说这块2450万像素部分堆栈传感器的强项可能在视频领域可以更加被激发出来。
# 2450万像素加上高读取速度，使得尼康Z63机内可录制6K/60p 4K60p无裁切N-RAW视频、4K120p
# 1.5系数裁切视频以及1080p240p微裁切视频。 并且视频的果冻效应控制比较好。
# 尼康Z36也拥有双增益ISO，档位分别为800与6400。但尼康明显是有所保留，其实再往上调12800也是可用。相机的整体高感表现确
# 实不错，如果一味的增加像素，可能就没有如此出色的高感表现了。配以与尼康Z9、Z8同样的对焦性能，尼康Z63更轻一下，最合适
# 上稳定器。
# 尼康算是这几年在内录RAW视频方面走在头部的厂家之一了，事实上内录N-RAW也确实好用，后期调整幅度更大，差别真的就和调整J
# PG格式和RAW格式照片那样。不过因为码率较高我手上的256G的存储卡只能录制半个小时左右的4K60pN-Raw和16分钟的6K60pN-Raw视
# 频。所以如果是视频创作者，建议购买更大的CFB卡，或者上个录机。
# 另外这次Z63的加厚机身对于散热也有帮助，最近使用下来感觉我是还没有摸到他的温控阈值。
# 保持优秀传统
# 这次尼康Z63采用的处理器为EXPEED
# 7。对焦、追焦能力提升很多。除了支持9种拍摄对象识别外，暗光环境下的对焦性能稍有提升。
# 但是大家相机拿到手上如果觉得相机对焦速度不够快，一定记得去设置界面里面调整一下，尼康原厂出来的时候将对焦速度调到中
# 间，这样设置总会给人慢半拍的感觉，如果将对焦设置调整为最快，整体对焦效果会好不少。
# 除了以上这些外观特点外，尼康Z63依旧”坚如磐石“。同时减震也依旧不错，支持8级防抖，手持拍摄也能保持相对稳定。
# 对我来说
# 2017年的时候我还在上大学，通过寒假兼职赚了3000元才买了我人生中的第一台尼康相机——D7100，2020年，我又购买了尼康第一台
# 微单相机——尼康Z6，直到现在它仍然是我的主力相机。
# 而当Z63发布的时候，我换设备的心又蠢蠢欲动起来，经过这段时间使用，我觉得尼康Z63确实有着同级别微单中较出色的视频性能
# ，6K60p无裁切N-RAW视频内录，这个功能在2w以下价位独此一台，虽然没有给新的N-Log曲线，但RAW视频却给了更多的调整空间，
# 尼康Z63也确实是一台合格的视频拍摄的水桶机。
# 照片方面，虽然依旧是2450万像素的传感器，但也意味着出色的宽容度与高感依旧被烙印在这台Z63中，并且皮肤柔和和灵活色彩优
# 化校准也加入到了尼康Z63中，整体画质表现依然是全画幅微单中的佼佼者。
# 当然，从尼康Z63发布至今被讨论最多的还是价格，毕竟尼康Z63相比起尼康Z62的首发价高了近5000元，但随着发布时间的推移，现
# 如今的Z63已经降价了几千元，随着价格下降Z63的性价比确实越来越高了。
# 所以不出意外，这将会是我的下一台尼康微单，毕竟现在的我视频拍摄需求日益增加，尼康Z63虽然没有旗舰相机Z9、Z8的8k录制，
# 但对于我来说4K60p无裁切已经足够90%的拍摄场景了，何况更高的录制规格会带来更大的存储压力，当然如果硬要说尼康目前视频
# 方面的短板，我觉得编码确实是一个短板，但在收购RED之后，相信未来尼康的编码会越来越好，也期待尼康Z63未来的鸡血固件。
# 尼康（Nikon）Z6III 【京尊达配送】(Z6 3/ Z63 / Z6三代 ) 全画幅微单机身
# 京东
# 月销量1000
# 好评率99%
# 无理由退换
# 京东配送
# ¥15699
# 优惠劵
# ¥ 1000
# 购买
# #深度好文计划#
# 举报/反馈
# 评论 21
# 发表
# czl6668887
# 他就是在做广告，价格太高了，视频功能强，我不喜欢，喜欢摄影功能强
# 2024-08-19
# 江苏
# 回复
# 1
# 南向科技作者
# 降价了已经
# 2024-08-19
# 福建
# 回复
# 赞
# 桀骜不驯UnyieldM
# 我就想要这款相机，想听听你的缺点，和r6对比，我两个都有，尼康Z63更好。
# 2024-08-19
# 回复
# 1
# 南向科技作者
# 在强蓝色光源下，蓝色溢出还是没有解决
# 2024-08-19
# 福建
# 回复
# 1
# 南向科技作者
# 视频编码还是偏大，占体积
# 2024-08-19
# 福建
# 回复
# 赞
# 金牛锺离如意5T
# 用的什么镜头？
# 2024-08-19
# 河南
# 回复
# 2
# 南向科技作者
# 我现在主要用z24-120mmF/4s
# 2024-08-19
# 福建
# 回复
# 1
# 金牛锺离如意5T
# 谢谢！
# 2024-08-22
# 河南
# 回复
# 赞
# 喜欢cola的萌萌
# 看完你的分享，我差点以为你在为尼康做广告，不过确实，Z63是真的香！
# 2024-08-18
# 回复
# 4
# 南向科技作者
# 我用完是觉得还挺适合我的，没有完美的设备，只有合适的设备，我期待它价格再下降一些
# 2024-08-18
# 福建
# 回复
# 3
# 二婉F
# 请问Z63拍照时，如果环境光暗，它会自己调高ISO来确保正常曝光吗？我想要这种自动ISO调节的相机
# 2024-08-19
# 回复
# 2
# 野花野草C
# 你应该先学学，这个问题就是个笑话
# 2024-08-20
# 安徽
# 回复
# 2
# 神静年泡0g
# 任何一款相机都可以设为ISO自动连手机都可以。
# 2024-08-19
# 山东
# 回复
# 1
# Amsterdam的黑甲骑士
# 请问这个相机比起富士xs10怎么样
# 2024-08-21
# 回复
# 赞
# 房高利
# 为何不3600或4500万像素
# 2024-08-19
# 四川
# 回复
# 1
# 金陵老夏
# 文章写的中肯
# 2024-08-19
# 江苏
# 回复
# 1
# 江南秦郎
# 上俄罗斯前线用
# 2024-08-27
# 陕西
# 回复
# 1
# 钢毅杰88
# 像素依然挤牙膏
# 05-04 13:35
# 北京
# 回复
# 赞
# 野生影评人
# 尼康Z63，不仅是摄影器材，更是创作的伙伴。细节处理非常到位，手感与功能兼具，镜头语言太绝了！
# 2024-08-20
# 回复
# 赞
# 宽面人不吃芝麻酱
# 挺好的，实实在在，但用词不当。如“画质非常好”不应说“碾压”而应说“相比”或“相对于”。
# 2024-08-21
# 回复
# 赞
# zjchen26
# 2024-08-20
# 日本
# 回复
# 赞
# 没有更多啦
# 南向科技
# 5849获赞 1328粉丝
# 更好感受生活 数码 摄影 旅行
# 关注
# 作者最新文章
# 2025年618，尼康相机如何选购，看这篇就够了！
# 21小时前
# 594阅读
# 改款A7M4？小FX3？索尼正式发布FX2！
# 2天前
# 267阅读
# iPhone 16 Pro Max值不值得买？半年真实体验告诉你答案！
# 3天前
# 2363阅读
# 相关推荐
# 尼康相机质量怎么样值得买吗？推荐10款性价比高的！
# 丸子评测
# 佳能和尼康单反相机哪个值得买？性能、口碑与选择
# 电子好物探
# 尼康（Nikon）Z6III（Z6 3/ Z63 / Z6三代）全画幅微单机身
# 雅钰
# 2025年618，尼康相机如何选购，看这篇就够了！
# 南向科技
# 尼康Z6III和尼康Z7II哪个更适合你？对比后差距明显
# 易懂家电
# 换一换
# 1
# 外交部深夜发声：勿要玩火
# 沸
# 2
# 新王加冕！巴黎5比0国米首夺欧冠
# 新
# 3
# 这些端午节的别名你知道吗
# 4
# 河南鹤壁一水库水位下降现千佛石窟
# 热
# 5
# 陈小春演唱会上座率高得惊人
# 6
# 巴基斯坦上将聊歼-10CE嘴角压不住
# 新
# 7
# 演员贾冰减肥成功瘦到脱相
# 新
# 8
# 荣昌政府食堂推出六一套餐
# 新
# 9
# 贾乃亮晒与甜馨端午节合照
# 10
# 印度首次承认印巴冲突中战机被击落
# 热
# 21
# 36
# 收藏
# 分享
# 设为首页
# © Baidu
# 使用百度前必读
# 意见反馈
# 京ICP证030173号
# 京公网安备11000002000001号
#
# [尼康Z63优缺点评价!来看到底值不值得买!](http://www.baidu.com/link?url=KU7_tTyrdoKI8HOeF9EZNYT-h43zEipzD6U5_czFz-ggo
# yQBmN6-U4OInw-KsmejvzKLG0a0NSyT4BbmWx0eHq)
# 发布时间: 未找到日期
#  首页
# 番剧
# 直播
# 游戏中心
# 会员购
# 漫画
# 赛事
# 登录
# 尼康Z63优缺点评价！来看到底值不值得买！
# 70
# 0
# 2025-03-31 12:30:00
# 未经作者授权，禁止转载
# 关注
# 登录 免费享高清视频
# 试看30秒
# 00:02 / 01:19
# 自动
# 倍速
# 1人正在看
# ，
# 已装填 0 条弹幕
# 请先登录或注册
# 弹幕礼仪
# 发送
# 2
# 投币
# 收藏
# 分享
# 我的出片好装备
# 微单
# 评测
# 尼康
# 相机
# 摄影
# 尼康z63
# 摄影器材
# 评论
# 正在玩命加载…
# 雨后彩虹的使者
# 发消息
# 关注 1082
# 弹幕列表
# 好好好，现在AI还能这么玩是吧？！
# 有问题，问豆包！
# 摄影
# （122/245）
# 自动连播
# 16.9万播放
# 简介
# 订阅合集
# 尼康Z6II 尼康Z62全画幅微单相机，成色有98新，
# 01:08
# 尼康（Nikon） Z 6II（Z6 2 Z62）二代专业级全画幅微单相机
# 01:09
# 目前全画幅相机性价比的一个选择，尼康z62，考虑到z63的底子还是传奇耐用王
# 03:41
# 尼康（Nikon）Z 6 II全画幅微单机身
# 02:25
# 松下紧凑型系统相机LUMIX G9上手教学
# 06:26
# 松下G9相机定时拍摄，轻松捕捉连续画面，让每一帧都充满生命
# 00:27
# 松下G9拍视频参数设置 补充：快捷键Fn1可以设置对焦
# 12:38
# 松下G9II打鸟4K60帧一镜到底不剪裁，有多远拍多远！
# 07:54
# AcePro2运动相机，去有雪的地方
# 02:53
# 运动相机画质天花板Ace Pro 2来了！ 拥有徕卡滤镜的运动相机简直不要太爽！
# 00:26
# 你拥有的不止是运动相机，是拥有徕卡滤镜8K画质的运动相机
# 00:28
# 老大测试了，老二必须来一个 影石insta360acepro2测试篇
# 00:40
# 尼康（Nikon） Z 7II Z7ii（Z7 2 Z72）专业级全画幅微单相机
# 00:23
# 尼康 Z6III 与尼康 Z7II - 图像质量评测
# 16:46
# 尼康Z72 摄影器材
# 00:36
# 加入尼康，来听一下Z7II的快门声吧！
# 00:56
# 松下S9枫叶季，相机中的绯红浪漫，醉了时光
# 00:24
# 松下S9 有颜值、有性能、全画幅、好上手、还不贵！
# 01:02
# 可能是全画幅中最小最轻的变焦头？松下18-40mm S9的轻巧机身加上仅重约
# 04:36
# Leica徕卡D-LUX 8多功能便携数码相机 ，真心推荐！
# 00:15
# Leica徕卡D-LUX 8多功能便携数码相机哦！
# 00:16
# Leica徕卡D-LUX 8多功能便携数码相机
# 00:19
# 13800元 徕卡D-Lux 8便携卡片相机上手体验！
# 04:24
# zv1拍摄实测，对比14pro。防抖不如手机。.
# 01:40
# hi好久不见，索尼zv1拆箱
# 01:18
# 索尼ZV1 卡片机 久等了
# 04:42
# 适合新手的索尼zv1超详细使用教程来咯！
# 08:40
# 尼康（Nikon）Z 8（Z8 z8）全画幅数码专业级微
# 00:08
# 尼康（Nikon）Z 8 全画幅微单 专业级数码相机 精准自动对焦8K视频拍摄高速连拍
# 00:18
# 尼康Z 8 全画幅微单 专业级数码相机
# 01:15
# 【御成尼康】Z8还是Z9？尼康两台顶配机身的选择思路！
# 03:25
# 【御成萌新君】尼康Z8教程66：像素变化拍摄功能
# 01:26
# 尼康ZFC 经典复古外观 高清摄影拍照视频.
# 00:20
# 尼康Zfc 入门级数码微单相机 经典复古外观 高清摄影拍照视频.
# 00:15
# 尼康（Nikon） Zfc 入门级数码微单相机
# 00:14
# 尼康（Nikon） Zfc 入门级数码微单相机 经典复古外观
# 00:22
# 【性价比微单推荐】尼康Z72微单相机 专业画质非常优秀入手不亏！
# 01:01
# 尼康Z7II，真心推荐！
# 00:41
# 尼康（Nikon）Z7II 全画幅专业微单5轴防抖全新Z7二
# 00:21
# 尼康Z7II 全画幅专业微单5轴防抖全新Z7
# 00:26
# 从购买到放弃的--第三期（松下S5m2） PS 说出来你可能不相信有点拧巴
# 06:50
# S5M2 不仅性能优秀，还支持多种接口，更方便专业摄影工作者
# 00:39
# 2060镜头秒变20-120焦段
# 00:27
# 【首发】松下S5二代值不值得购买，让我来告诉你！画面真美！
# 02:22
# Insta360很懂用户！新增功能：车牌遮挡特效+云端存储
# 02:35
# AI剪辑，小白也能剪出炫酷视频
# 00:27
# Insta360 X4 全景相机对我来说一直是一个新鲜但又很遥远的品类，
# 07:25
# 影石全景相机x4 影石运动相机
# 00:27
# 准新影石x4，带原厂自拍杆和大力夹。
# 00:59
# 这么省事的全景相机你尝试了嘛？
# 01:00
# 这画质，X4你别太离谱！
# 00:17
# 运动相机测评‼️不会用的看我这篇‼️ Insta360 X4 巨巨巨好用啊！
# 01:19
# 尼康（Nikon） Z5入门全画幅数码微单相机
# 00:34
# 尼康Z5 全画幅微单镁合金机身
# 01:03
# 尼康z5入门级微单相机推荐
# 01:14
# 尼康Z5 z5全画幅微单数码相机 Vlog视频拍摄旅游
# 01:04
# 最具性价比入门全画幅微单
# 03:09
# 这可能是全网最详细的尼康Z5使用教学第一期；尼康Z5教程
# 14:03
# 听说这是年轻人的第一台全画幅微单相机！你们觉得呢？
# 01:04
# 人生的第一款全画幅相机---尼康Z5拆箱视频
# 06:45
# 满分手机稳定器长什么样？大疆OSMO Mobile 6浅银灰
# 02:31
# 户外直播就用它！简单方便 还能稳稳跟随~
# 00:22
# 过年回家就用它，大疆OM6 你的年味视频好搭子！
# 00:12
# 大疆这款Osmo Mobile 6给我太多惊喜了吧！
# 00:24
# 云台倾斜了？ 我来教你怎么办！
# 00:29
# 一起学习大疆 DJI Osmo Mobile 6 OM手机云台稳定器
# 02:47
# 一定是地下太潮了！兵马俑都学会大疆小曲了
# 00:11
# 新手天菜，上手沦陷｜大疆手持云台 大疆OM6好用到不像话！
# 01:03
# 【旗舰店】GoPro HERO12 Black防抖运动相机5.3k高清防水
# 00:30
# 【GoPro12运动相机】没有1英寸传感器，又双叒挤牙膏？
# 05:19
# GoProHERO12 Black是有史以来最佳画质和稳定性最强的HERO相机.
# 00:34
# GoPro12 Gopro12穿越机拍摄参数设置
# 00:45
# 再燃热情，GoPro Hero12新一代运动相机，挑战天花板
# 01:12
# 油管大神：fabreezy 丨 The GoPro HERO 12
# 02:59
# 一起认识 #GoProHERO12 Black -
# 00:25
# 我不信你看完还不会选Gopro12和Action4！
# 06:14
# 2025年佳能R62还值得购买吗？
# 01:02
# 佳能（Canon）EOS R6 Mark II来了！
# 00:25
# 佳能（Canon）EOS R6 Mark II
# 00:41
# 佳能R62和索尼A7m4 到底该怎么选？
# 08:25
# 这样的性价比全画幅佳能R6二代你真的不心动吗？
# 00:16
# 用过佳能R6Ⅱ才知道什么叫真香！
# 01:21
# 全画幅选佳能R6II还是索尼A7M4呢？
# 01:11
# 佳能全能型相机标杆--R6II
# 00:36
# 2024 年最佳预算半画幅设置 - 索尼 A6400 和适马18-50mm F2.8
# 05:37
# 索尼（SONY）ILCE-6400 a6400L 半画幅微单
# 00:32
# 索尼（SONY）ILCE-6400 a6400L 半画幅微单
# 00:31
# 索尼（SONY）ILCE-6400 a6400L 半画幅微单
# 00:52
# 新拍照设备到手，2025争取拍出高质量作品
# 02:10
# 索尼全系入门半画幅（apsc）相机；最让人如鲠在喉的地方在哪里？
# 02:50
# 索尼a6400，这可能是你四五千预算能买到最全能的微单相机
# 01:48
# 索尼A6400，现在还是入门首选吗？
# 02:38
# 适马24 - 70 F2.8二代超厉害！焦段广，
# 01:58
# 适马 24-70mm F2.8 DG DN 镜头下的漂亮小姐姐
# 02:28
# 适马24-70 2.8一代 适马24-70 2.8二代
# 00:34
# #镜头 适马24-70mm F2.8 DG DN Art的评测
# 02:01
# 这是一支值得您焊到相机上的镜头！
# 01:18
# 已确认部分SIGMA 24-70mm F2.8 DG DN II
# 00:09
# 索尼VS适马 24-70 F 2.8 都是二代应该怎么选
# 04:24
# 适马24-70mm F2.8 DG DN第二
# 03:23
# 非常轻便的超长焦镜头-腾龙150-500
# 01:09
# TAMRON腾龙 超长焦150-500mm F 5-6.7 开箱分享
# 06:19
# 500mm超长焦，近在咫尺
# 00:25
# 【顾俊】不需要钞能力，也能拥有超长焦！腾龙150-500mm！
# 10:50
# 长焦快乐头！腾龙150-500mm f5-6.7上手实拍体验！
# 06:07
# 我的第一支超长焦变焦头—腾龙150-500mm F 5-6.7
# 09:30
# 腾龙150-500怎么样
# 00:25
# 腾龙150-500试拍
# 02:44
# Osmo Pocket3配件磁吸支架底座
# 00:36
# 适用大疆DJI OSMO Pocket3磁吸
# 00:19
# 支架pocket3保护壳拓展框兔笼
# 00:27
# 纽尔适用于Pocket3磁吸支
# 00:24
# 想要让你的大疆OSMO POCKET3解锁更多玩法吗？
# 00:28
# 相机支架，手机支架拍摄
# 00:24
# 纽尔适用于Pocket3磁吸支架
# 00:22
# 纽尔适用于Pocket3磁吸支架pocket3保护壳
# 00:21
# 开启尼康 Z6III 约120幅 秒的高速连拍，
# 00:48
# 比上代贵5000元？它够强吗？尼康Z6III上手
# 14:51
# 尼康z6iii三代z63全画幅微单机身
# 00:22
# 尼康Z63 Z6III Z6三代来了！
# 00:25
# 尼康Z63 Z6III Z6三代 全画幅 高清摄影拍照数码微单相机
# 00:42
# 尼康Z63优缺点评价！来看到底值不值得买！
# 01:20
# 尼康Z63新机到手保姆级教程
# 10:39
# 尼康Z63现在到底能不能买？ 其实Z63现在的参数和体验
# 01:41
# 【保姆教学】尼康Z30 Z50 ZFC视频拍摄指南
# 14:05
# 尼康（Nikon）Z50入门级微单相机
# 00:09
# Z50二代开箱 尼康Z50二代摄影
# 03:16
# 第六期新手相机推荐测评，假设各位想看别的相机，
# 04:12
# 6199元 新手摄影友好相机 尼康Z50II入门微单上手体验
# 04:55
# 新手入坑尼康，到底该怎么选相机
# 01:43
# 聊一聊一万元左右，我认为目前性价比最高的全画幅微单
# 02:38
# 可能是全画幅中最小最轻的变焦头？松下18-40mm S9的轻巧机身加上仅重约
# 04:36
# 从5K到8K，6年了，松下现在有哪些值得买的性价比神机？
# 14:22
# 【御成phot】悠闲旅人：松下S9体验分享 2024年中松下发布的S9，
# 05:56
# 一台紧凑型的全画幅微单相机 或许它适合你「松下s9」
# 03:38
# 提前锁定2024最轻便颜值最高全画幅微单？松下S9极速上手！
# 12:33
# 松下也玩“小轻新”？18-40挂机小饼干上手体验
# 03:05
# 松下新款18-40镜头
# 00:27
# 【佳能V1】自费原价购入！防抖拉胯夜景崩？
# 04:50
# 【沉浸式开箱-佳能PowerShot V1】 PowerShot V1随身视频机
# 01:15
# #楠哥的课 佳能PowerShot V1 初步上手体验
# 01:21
# 佳能v1 新机测评！
# 01:26
# 性能及画质实测 佳能PowerShot V1深度体验
# 16:23
# 小型轻量高画质的随身视频机PowerShot V1开箱介绍来啦
# 01:33
# 能塞进口袋的4K视频机——佳能Powershot V1
# 02:31
# 口袋电影机？佳能PowerShot V1的LifeStyle 抛开参数
# 04:37
# 3年前的高颜值微单尼康Zfc值得买吗？
# 03:14
# 3个设置搞定尼康Zfc，新手这样设置更出片
# 01:36
# 相机推荐尼康zfc
# 00:28
# 这是一台颜值与性能共存的相机
# 00:42
# 这样一台颜值与实力并存的相机，你心动了吗？
# 03:44
# 新手相机入门推荐之尼康ZFC
# 00:55
# 入坑了才发现摄影是用光的艺术
# 01:49
# 尼康半画幅 Zfc 上手体验｜复古外观，2088W像素，新手入门好机器！
# 00:37
# 半画幅不适合拍人像？佳能EOS R7人像实拍来战！
# 08:32
# R7保姆机使用教程，扔掉说明书一个视频就学会
# 12:46
# 2025年佳能R7还香吗？半画幅相机推荐
# 05:11
# 佳能EOS R7旅拍体验测评，4K素材分享
# 07:50
# 新手相机入门推荐之佳能R7
# 00:57
# 新手必看干货，佳能R7上手即用教学；10分钟教会你使用佳能R7相机
# 14:47
# 相机推荐之佳能EOS R7！
# 00:54
# 七千多的r7还不抓紧来冲！
# 00:59
# 35-150到底是黄金人像镜头还是一只变态镜头
# 00:42
# 【御成尼康】梦幻变焦来袭！腾龙35-150mm F2-2.8尼康Z卡口上手测评
# 03:22
# 一镜走天下 腾龙35-150F2-2.8
# 00:09
# 这期视频，咱们来说一说腾龙新出的35-1.
# 01:58
# 选腾龙35-150还是选一群小定焦
# 00:34
# 万金油镜头-腾龙35-150，摄影器材推荐
# 00:46
# 腾龙宣布开发适用于尼康Z卡口的新型 35-150mm f
# 00:09
# 腾龙全画幅人像变焦镜头35-150MM F2.8，沉浸式开箱
# 00:27
# 尼康 Z5II 新品开箱 & 性能推荐！
# 04:50
# 尼康 Z5Ⅱ是最强入门全画幅微单？
# 03:58
# 明与暗，动与静，在尼康Z5Ⅱ面前都不是问题！
# 03:49
# 力压传奇连拍王-尼康Z5Ⅱ上手体验
# 05:22
# 去找自由的海 ：尼康Z5II 人像摄影
# 00:52
# 年轻人的第一台全画幅!2025年尼康Z5值不值得买？
# 07:51
# 尼康新品Z5II 重新定义全画幅新势力
# 00:53
# 尼康新机 Z5II 相辅「像」成 Z5II搭载全画幅背照式CMOS传感器，
# 00:09
# 保姆教学：给新手的佳能R8使用指南
# 14:28
# R8八项全能全画幅，年轻人的第一台微单相机，
# 00:38
# 7800抄底佳能R8值得吗？无惧阉割，实用配件合集
# 08:27
# 2024全画幅微单性价比首选R8
# 06:17
# 一个视频告诉你，佳能R8 到底值不值得购买！
# 02:22
# 新手相机入门推荐之佳能R8
# 00:55
# 新手必看干货，系统化的佳能R8相机使用教学
# 01:23:24
# 万元以内必入的全画幅相机【佳能R8】
# 00:50
# ⚡⚡⚡佳能新品R50V开箱⚡⚡⚡
# 00:46
# ¥4799元的专业视频机？佳能 EOS R50 V 新品解读
# 09:38
# 佳能R50V 已到店
# 00:59
# #佳能 佳能新品“创意视频机”R50 V开箱！
# 00:40
# 佳能10秒就可以学会的电影感教程，建议收藏
# 00:34
# 创意无限，青春有V！佳能青春专微视频机EOS R50 V 释放你的无限灵感。
# 00:30
# r50v他怎么敢的，居然炒到7000块
# 01:42
# 为视频而生的EOS V系新视频机
# 06:54
# Ace Pro 2相机横竖拍切换
# 00:47
# 【旗舰画质】影石Insta360 Ace Pro 2旗舰影像运动相机
# 01:51
# 影石徕卡影像挑战赛，AcePro2运动相机
# 00:19
# 救命！影石Ace Pro2街拍也太绝了吧！
# 00:54
# 专业影像，清晰画面，细致呈现，影石insta360
# 00:21
# 在春天里起舞！这油菜花田也太美了～
# 00:16
# 运动相机街拍！靠谱吗？ 影石AcePro2
# 01:29
# 影石运动相机acepro2拍摄效果到底怎么？
# 01:01
# 首发评测大疆视频眼镜N3!沉浸式飞行体验大革新
# 03:37
# 首发评测大疆N3视频眼镜 极致沉浸
# 03:37
# 全网首发 N3眼镜安装视频
# 06:07
# 每台飞机的性能都应该压榨到极致 这才是NEO的第四型态
# 00:21
# 今日推荐相机 尼康Z5，一款入门全画幅微单相机，
# 01:28
# 还记得你的第一台相机吗
# 01:01
# 传奇连拍王尼康z5最全介绍来啦
# 03:00
# 尼康（Nikon） Z5入门全画幅数码微单相机
# 00:34
# 新手相机推荐之“尼康Z5”
# 01:08
# 年轻人的第一台相机？
# 00:48
# 年轻人的第一台全画幅微单相机尼康Z5，还记得你的第一台相机吗？
# 01:11
# 年轻人的第一台全画幅!2025年尼康Z5值不值得买？
# 07:51
# 尼康Z 24-120mm F4镜头评测：画质和光学素质不错
# 01:29
# 尼康24-120 全画幅镜头24-120mm f4 S-Line
# 00:24
# 风光镜终极组合？尼康Z24-120与Z100-400深度体验
# 10:04
# 【御成尼康】销量最高的变焦？Z24-120使用分享
# 01:39
# 尼克尔 Z 24-120mm f 4 S 易于携带的多倍变焦镜头
# 00:19
# 尼康全画幅微单相机和它的好机友三件套镜头开箱 24-120MM F4
# 00:28
# 尼康Z24120F4S这只镜头怎么样？ 一条视频告诉你~
# 01:12
# 尼康Z24120F4S上机效果怎么样？
# 00:55
# 奥之心OM3开箱视频
# 01:29
# 奥之心 OM-3 初次使用介绍
# 01:55
# 奥林巴斯你倒闭是有原因的，奥之心om3一万五我买你？
# 01:54
# 奥林巴斯 OLYMPUS OM-3奥之心 微单相机
# 00:27
# 复古设计+堆栈CMOS 奥之心OM-3微单动手玩
# 02:16
# 迟到的om3评测，2025年你会选一台m43吗 ？
# 04:40
# 奥之心新品OM-3海外官宣终于要来了
# 00:16
# 奥之心新品，om3实拍图，看看它的直出色彩表现力如何
# 00:33
# 奥林巴斯OM5来咯 ，适合新手的相机推荐
# 00:25
# 奥林巴斯em5一代+14-42镜头 1700 【相机介绍】
# 01:08
# 奥林巴斯EM5 捕捉瞬间，定格精彩！
# 01:10
# 奥林巴斯 奥之心om5沉浸式开箱！
# 00:39
# 奥林巴斯 OLYMPUS OM-5奥之心 微单无反相机
# 00:35
# 这样不惧风雨的奥之心，有没有击中你的心呢？
# 01:08
# 天呐，竟然有满足这样的相机存在，复古颜值，小巧轻便，
# 01:08
# 家人们，新相机到了，奥之心om-5开箱
# 04:14
# 独家首发奥林巴斯E-M5 II相机贴膜参考视频
# 41:12
# 奥之心的神奇对焦 喜欢对焦的同学就用奥之心吧
# 00:10
# 尼康D7500配18-200镜头，这是一台准新机
# 00:22
# 尼康D7500来喽，好东西一起分享
# 00:24
# 尼康D7500搭配18-300镜头，一镜走天下
# 00:26
# 尼康D7500搭配18-140，买了没用几次，
# 00:38
# 尼康D7500单机专业中端高清数码单反相机
# 00:47
# 03:41
# 目前全画幅相机性价比的一个选择，尼康z62，考虑到z63的底子还是传奇耐用王
# 雨后彩虹的使者
# 2.9万
# 19
# 02:55
# Z52和Z63怎么选？我带着它去拍了一场实战，有了答案
# 皓摄影
# 5.5万
# 35
# 06:57
# 尼康Z52，拒绝吹捧！合理评价，尼康迟到两年的入门全画幅相机
# 卡密影像日记
# 8778
# 120
# 02:16
# Z5II ZF Z6III怎么选？
# 是我阿星
# 1.7万
# 4
# 04:58
# Z52不严谨测试,去实体店跟Z63拍了点对比片，我震惊了！
# 吉你两刀
# 1.3万
# 45
# 03:45
# 尼康z63 三个月使用感受分享
# 幺八八科技
# 9789
# 12
# 01:30
# 尼康z63和vivox200ultra户外画质实测
# 代瑞023
# 6115
# 18
# 03:26
# 佳能R8:全画幅里的“小钢炮”，优缺点让我笑中带泪
# 拍摄键
# 1206
# 2
# 07:28
# 谁是万元档最强机？尼康Z52和索尼A7C2该选谁？
# Anti-lover
# 2.5万
# 9
# 13:56
# 全画幅微单守门员再升级？尼康Z5II究竟值不值得买？
# 马丁先森-Martin
# 1.9万
# 102
# 04:30
# 尼康z63和vivo x200ultra 画质对比
# 代瑞023
# 5465
# 21
# 01:22
# NRAW SDR｜尼康Z63 调色测试｜随手拍｜阿莱｜4K60｜达芬奇
# 尼古拉斯七叔
# 800
# 0
# 03:32
# 国产黑马杀疯了！超广镜头新卷王——星曜12mm F2.8 全画幅 E 卡口镜头深度测评
# 原来是大椿
# 2.1万
# 9
# 02:42
# 尼康Z63转接适马150-600C版拍鸟图片展示
# 大自然爱好者E
# 1408
# 1
# 00:14
# 就这么水灵灵的装好了，AW3225QF 31.5英寸4K
# 雨后彩虹的使者
# 11
# 0
# 03:47
# 为什么日本相机称霸全世界？日本相机是如何崛起的？
# 破局研究所
# 1.6万
# 14
# 19:25
# 尼康云创功能系统化使用教学，支持尼康Z63/Z52/Z50Ⅱ/ZF四款机型
# 常远-硬核摄影教学
# 2.6万
# 25
# 02:08
# vivo X200S真实用户告诉你值不值得买
# 不寻常手机测评
# 5.6万
# 25
# 04:48
# 尼康Z5II 电影感旅行全画幅
# 克里斯的大冒险
# 2689
# 3
# 00:19
# 不会吧？你的相机竟然不能直播？我给手机塞进去一个全画幅微单，虽然目前还是丐版风格，但成功解决了手机画质差，单反相机
# 不能直播的缺点，可以使用手机内置任何滤镜
# 酷玩相机改装客
# 2.1万
# 2
# 展开
# 投稿安利好动画，赢现金好礼！
#
# [尼康Z6
# III深度评测:性能炸裂,视频党狂喜,但这点让人纠结……](http://www.baidu.com/link?url=Ldcwp-YpUMqYFoNSFaF4AD2KQNsBcApgUpM
# lEbIiFT2gLqnJOK23-Ry51p6MxVuXHE8-nE5l319j57ii4laleG4mTJd87xiFFj1uoey6gLG)
# 发布时间: 2025年4月12日
#  百度首页
# 尼康Z6 III深度评测：性能炸裂，视频党狂喜，但这点让人纠结……
# 花花鱼好物分享
# 2025-04-12 23:14
# 湖北
# 导读
# 地铁口逆光抓拍睫毛根根分明，暴雨中防水胶圈多到拼乐高，6K
# RAW内录让调色高光拉回，对焦如502胶水粘住瞳孔。万元机逼出六边形战士，能拍清刘翔跨栏与女友眼线，钱包哀嚎却让私房摄影
# 师秒变夜视仪。
# 内容由AI智能生成
# 有用
# 全画幅微单江湖又掀血雨腥风！尼康憋了两年的大招Z6
# III，竟把万元机逼成了"六边形战士"？连夜实测3周，这相机让我又爱又恨…
# 🔥 连夜拆箱惊了！这五大杀招太残暴
# 1️⃣ 拍电影再不用租设备！
# 深夜测试6K RAW内录差点泪奔——12档动态范围调色时高光居然能拉回！搭配240帧慢动作，拍我家二哈拆家都能出王家卫大片感📽️
# 2️⃣ 对焦玄学被终结！
# 地铁口逆光抓拍小姐姐，睫毛根根分明！猫咖里主子720度转体跳跃，对焦框像502胶水一样死死粘住瞳孔👁️（别问为什么在猫咖测评
# ）
# 3️⃣ 取景器竟能当显示器？
# 40度高温下屏幕亮得像开了「写轮眼」，隔壁索尼大哥默默掏出了遮光罩…翻转屏自拍终于不用扭成瑜伽教练了🤳
# 4️⃣ 淋雨实测打脸黑粉！
# 暴雨天冲进迪士尼（别学！），机身接缝处藏了秘密武器——防水胶圈多到能拼乐高！就是镜头起雾时保洁阿姨看我的眼神很微妙🌧️
# 5️⃣ 双卡槽暗藏心机！
# CFexpress卡录ProRes，SD卡直出朋友圈装X，社畜拍完客户片秒传手机发某音的骚操作被拿捏了🤏
# 💔 三大暴击！钱包在哀嚎
# ⚠️ 动态范围暗箭伤人
# 拍故宫落日时高光过曝0.5档，被迫P掉栏杆上的"正大光明"匾（皇上饶命！）风光党慎入，除非你想成为PS大师💻
# ⚠️ 电池续航魔咒再现
# 漫展拍小姐姐3小时换4块电池，被当成卖充电宝的黄牛…建议尼康改名叫「电动牙刷厂商」🔋
# ⚠️ 价格刺客名不虚传
# 单机身够买60杯酱香拿铁！海鲜市场Z6 II突然爆卖，二手贩子连夜给我发红包🙃
# 🤔 这四类人现在立刻马上冲
# 拍娃党/宠物奴：熊孩子百米冲刺都能拍出《谍影重重》既视感
# 自媒体卷王：6K视频让甲方爸爸以为你换了RED电影机
# 私房摄影师：-10EV暗光对焦比夜视仪还狠（咳咳）
# 尼康钉子户：D850老用户换机像回家，菜单都不用重新学
# ⚔️ 万元机大乱斗！
# 索尼A7M4：33MP高像素真香，但视频规格像上个世纪
# 佳能R6II：连拍快到能数清苍蝇翅膀，RF镜头贵到肉疼
# 松下S5IIX：V-log碾压全场，对焦还在用「抽奖模式」
# 血泪建议：
# 要直播带货选Z6 III（肤色美颜居然能打）
# 拍婚礼别犹豫（新郎跑再快都逃不过20张/秒）
# 学生党醒醒！这钱够买辆电驴了
# 💸 土豪套装指南
# 小白套餐：Z6 III+24-120mm，旅游拍妹通杀（2.5万肉疼警告）
# 导演套装：加Ninja V外录机，B站UP主瞬间变「X导」
# 富二代顶配：14-24mm F2.8拍星空，记得带劳斯莱斯当脚架
# 📢 最后暴言：
# 这相机像极了学霸校草——参数完美但有点高冷，价格这道坎比我家防盗门还难进…话说回来，能同时拍清刘翔跨栏和女友眼线的神器
# ，除了它还有谁？
# （评论区已开放，手持Z6 II的朋友请冷静）
# 尼康（Nikon）Z6III (Z6 3/ Z63 / Z6三代 ) 全画幅微单机身 高清摄影摄
# 京东
# 月销量1000
# 好评率99%
# 无理由退换
# 京东配送
# ¥15699
# 优惠劵
# ¥ 1000
# 购买
# 举报/反馈
# 评论 13
# 发表
# 螺蛳粉里没有螺蛳
# 三个小时用四块电池？可是为什么我的一块顶一两天又没问题
# 04-24 09:58
# 广西
# 回复
# 2
# HZCYMA
# 你是拍照 他是拍视频
# 05-08 13:30
# 浙江
# 回复
# 1
# 歪果仁李小龙
# 看完评测心痒痒，这相机对焦比猫还粘人，防水设计能拼乐高。钱包在抗议，但拍娃党可以冲了！
# 04-13 00:25
# 河南
# 回复
# 32
# 生吧语z
# 老师，尼康z6二代和z6iii怎么选择啊？
# 05-05 08:15
# 江西
# 回复
# 赞
# HZCYMA
# Z63是专业机 是上了一个台阶的机器 速度之快 用了爽歪歪的机器 只是像素比Z8少 不过2450像素足够清晰
# 05-08 13:37
# 浙江
# 回复
# 赞
# 白色羽毛tt
# 尼康是个靠谱的品牌，产品也是诚意的
# 04-14 00:48
# 云南
# 回复
# 3
# 微醺佟湘玉
# 尼康Z6 III，性能果然不凡，视频党大喜！只是这点小遗憾，饿滴神啊，还得琢磨琢磨。
# 04-14 21:06
# 回复
# 1
# 伟宇青g
# 对万元机 有误解了。 1000万 算万元机吗？ 我认为 1万左右 才真香
# 05-06 11:15
# 江苏
# 回复
# 1
# 老慈祥
# 最近Z6Ⅲ价格越来越贵，看来碾压Z5Ⅱ是真的。
# 04-22 21:48
# 北京
# 回复
# 1
# 在玄武湖跳皮筋的风信子石
# 除了视频，照片，跟尼康当年的半画幅d90神机没啥大的差别。放大可能不同。
# 04-15 11:46
# 北京
# 回复
# 赞
# lnaswxd
# 连夜实测3周 ，什么语法逻辑啊
# 04-21 08:57
# 辽宁
# 回复
# 赞
# zinzinzip
# 还以为售价仅需600
# 04-14 12:00
# 上海
# 回复
# 赞
# Mike的彩虹紫
# 谁还用Z62，快去升级Z63
# 04-20 02:29
# 安徽
# 回复
# 赞
# 没有更多啦
# 花花鱼好物分享
# 6.7万获赞 6348粉丝
# 电商爱好者，数码电子，美妆时尚好物分享
# 数码领域创作者
# 关注
# 作者最新文章
# 破壁机前十的有哪些品牌？热门机型排名分享
# 9小时前
# 1阅读
# 哪种破壁机好？口碑前十名榜单分享，助你选对优质品
# 8天前
# 14阅读
# 宠物净化器哪个牌子好？排名前10名品牌热门机型深度测评！
# 11天前
# 26阅读
# 相关推荐
# 佳能和尼康单反相机哪个值得买？性能、口碑与选择
# 电子好物探
# 尼康（Nikon）Z6III（Z6 3/ Z63 / Z6三代）全画幅微单机身
# 雅钰
# 尼康Z6III和尼康Z7II哪个更适合你？对比后差距明显
# 易懂家电
# 神牛V350闪光灯好用吗？摄影爱好者的必备神器
# 喵喵带货王
# 运动相机哪个牌子好又耐用，性能与品质皆不容小觑
# 测评侠哥
# 换一换
# 1
# 外交部深夜发声：勿要玩火
# 沸
# 2
# 新王加冕！巴黎5比0国米首夺欧冠
# 新
# 3
# 这些端午节的别名你知道吗
# 4
# 河南鹤壁一水库水位下降现千佛石窟
# 热
# 5
# 陈小春演唱会上座率高得惊人
# 6
# 巴基斯坦上将聊歼-10CE嘴角压不住
# 新
# 7
# 演员贾冰减肥成功瘦到脱相
# 新
# 8
# 荣昌政府食堂推出六一套餐
# 新
# 9
# 贾乃亮晒与甜馨端午节合照
# 10
# 印度首次承认印巴冲突中战机被击落
# 热
# 13
# 33
# 收藏
# 分享
# 设为首页
# © Baidu
# 使用百度前必读
# 意见反馈
# 京ICP证030173号
# 京公网安备11000002000001号
#
# [尼康Z63深度解析:旗舰技术下放,全能表现能否重塑中端市场格局...](http://www.baidu.com/link?url=CTISer_twRGhxkRIFR7qK3
# -kqtT6N2s07eUQI-v_iR3W_43D0QoMN3AMQ6qANkhc)
# 发布时间: 未找到日期
#
#
# [尼康Z63跌破1.2万,推荐购买](http://www.baidu.com/link?url=twjzmHB2-wymKGtFayMnnDpw2p6NpMYa6_Fg19WHFod7RwiJilTgdFZGn
# x9WmIH6IXoGdmz1CAAUJrfb1ERibCAjR9pE2BkZ0Nn0ola-HH7TNqPqMeBvq_0QDGVlesZ5)
# 发布时间: 2025年2月11日
#  百度首页
# 登录
# 旷野瞬息的风
# 2025-02-1104:08
# 关注
# 尼康Z63跌破1.2万，推荐购买！
# 大家好，今天给大家带来最新的尼康相机价格更新。尼康这家公司真是有点意思，原价的时候你可能觉得差点意思，但一旦打折，
# 性价比就立马显现出来了。
#
# 1️⃣
# 如果你计划在清明节或者五一假期出行，强烈推荐你考虑一下全画幅相机Z63或者复古系列的Zf。虽然63发布后我一直在劝大家别买
# ，觉得不值，但现在价格跌到不到1.2万，你还在犹豫什么？要知道，发布了三四年的R62和A7M4也是这个价位。当然，如果你打算
# 等今年春季的索尼和佳能新品，也可以，但从尼康的市场经验来看，这个价格应该不会涨到1.9万那么离谱。不过，现在63基本满血
# ，我觉得早入手不亏。Zf这款相机一直以来都有溢价，我之前预警过不值，但现在9k出头的价格，真是香得不行。毕竟这是一台颜
# 值很高的相机，特别适合扫街党。唯一的问题是，尼康能不能提升一下镜头的颜值，这可是买这台相机时最难的点。
#
# 2️⃣
# Z50二代的港水价格现在降了不少，但如果你不急，可以再等等。半画幅的入门市场，这个6k出头的价位应该还是比较卷的，真正降
# 到4、5k反而没有太大的降幅了。当然，如果你主要拍视频，Z30双套也够用了。50一代现在也不是不能买，依然推荐大家可以考虑
# 。
#
# 3️⃣ Z5、Z62、Z72这三个机型，建议优先考虑国行。如果一定要选，我觉得72会更好一些，前提是你没有很强的视频需求。
#
# 4️⃣
# 最后说说镜头，今天我增加了几个镜头的更新，主要是大家经常询问的。普通用户可以先买个24120F4，目前节后价格还有小幅回跌
# 。这个镜头是我就算卖了手里的Z8，都会留下的镜头。其他的镜头，我列出的都是尼康认为不错的。
#
# 希望这些信息对大家有所帮助，祝大家都能买到心仪的相机！📸
# 22
# 272
# 发表评论
# 发表
# 评论列表（22条）
# 梦幻岛上织梦境
# 比国内少花2k，挺值的
# 02-10 21:52
# 湖北
# 回复
# 赞
# 南寻北觅大智者秋雅
# 其实只便宜1k多，还没保修，这是港版水货价
# 02-10 21:53
# 河北
# 回复
# 赞
# Energize子芷
# 这个价格，买国行版不香吗？
# 02-20 12:57
# 北京
# 回复
# 1
# 学术贡献6
# 70200是多少钱呢
# 02-16 06:27
# 北京
# 回复
# 1
# 日祎忘05
# 1.2万那里买呢
# 04-21 07:00
# 广东
# 回复
# 赞
# 茄郭靖n
# 尼康Z63价格这么香，果断入手啊！拍出来的照片质感真的不错，旅行时带上它，记录美好瞬间！
# 02-19 08:28
# 江西
# 回复
# 赞
# 双杠昱酱
# 降到1.1就可以买了，63元超合适
# 02-21 00:30
# 北京
# 回复
# 赞
# 3D小云
# 这张图是香港版本还是非官方渠道获取的
# 02-13 08:31
# 中国香港
# 回复
# 赞
# 思考小蜜
# 关于z30的评价怎么样
# 02-20 13:41
# 江苏
# 回复
# 赞
# Data科技敏
# 比国行便宜2000，感觉还不错哦
# 02-14 16:54
# 浙江
# 回复
# 赞
# 迪士尼悠悠飞
# 有50250或18140镜头不
# 02-10 23:22
# 浙江
# 回复
# 赞
# 弗拉基米尔是个皮孩子
# z30怎么样
# 02-11 01:30
# 广东
# 回复
# 赞
# 郝大帅园丁四剪微感疼哟
# Z63咋买啊
# 02-11 01:21
# 江西
# 回复
# 赞
# 追逐梦想的月亮
# 70200啥价
# 02-10 22:21
# 河北
# 回复
# 赞
# 海洋边的吟游歌手
# 63降到1.1w就下手
# 02-11 01:07
# 四川
# 回复
# 赞
# 木木子学长
# 教育领域爱好者
# 这是港版正品还是水货呀
# 02-10 20:28
# 广西
# 回复
# 赞
# 真果伴侣共商分享汇
# 这价为啥不选国行呢
# 02-11 04:08
# 河南
# 回复
# 赞
# 长途跋涉同行纳达尔
# Z663有人带吗？
# 02-10 23:43
# 河南
# 回复
# 赞
# Mouse未来杰
# 有尼康的镜头吗，型号是50250或者18140
# 02-12 13:55
# 重庆
# 回复
# 赞
# Strength健平
# 有带Z663货的吗？
# 02-15 17:59
# 江苏
# 回复
# 赞
# 呱呱Titter
# 该如何购买Z63呢。
# 02-15 03:51
# 辽宁
# 回复
# 赞
# 查看更多评论
# 作者最近动态
# 旷野瞬息的风
# 2025-06-01
# 花青素抗氧抗炎，守护健康全明星✨ 在健康...全文
# 旷野瞬息的风
# 2025-06-01
# 精致生活不将就，小音响也能治愈心灵 在喧...全文
# +1
# 旷野瞬息的风
# 2025-06-01
# 流浪猫狗喂食陷阱！绝育才是关键！ 家人们...全文
# 旷野瞬息的风
# 2025-05-31
# 别把别人当傻子，真相自会大白⚠️ 谁都不...全文
# +7
# 旷野瞬息的风
# 2025-05-30
# 卡其色马丁靴🍂秋冬通勤万能百搭王 姐妹们...全文
# 旷野瞬息的风
# 2025-05-29
# CPU虚焊修后3月实测！保养指南速收🔥 ...全文
# +1
# 旷野瞬息的风
# 2025-05-28
# 莆田鞋逆袭！高质量≠山寨🔥 家人们谁懂啊...全文
# 设为首页
# © Baidu
# 使用百度前必读
#  意见反馈
#  京ICP证030173号
# 京公网安备11000002000001号
#
# Out: None
# [Step 1: Duration 38.68 seconds| Input tokens: 2,114 | Output tokens: 45]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extract information from the search results
#   nikon_z63_params = "2450万像素BSI背照式CMOS, EXPEED 7影像处理器, 1/16000秒快门速度,
#   机械快门14fps/电子快门20fps, 293/297点自动对焦点, 6K 12bit NRAW无裁切, 4K 60P ProRes RAW, 五轴7级或8级机身防抖,
#   576万像素EVF, 支持FHD 240P高格率录制, 改良翻转屏, CFexpress + SD双卡槽, USB-C 3.0, HDMI A, 支持Z6 III的Nikon NX
#   Studio新版本App。"
#
#   nikon_z63_price = "官方发布价2500美元，现在促销价15699元人民币。"
#
#   nikon_z63_user_review = "优点: 优秀的视频功能（6K 12bit NRAW无裁切, 4K 60P ProRes
#   RAW），出色的低光画质表现，高动态范围，强的防抖性能。缺点: 电池续航一般，价格偏高。"
#
#   nikon_z63_summary =
#   f"尼康Z63具有以下参数：{nikon_z63_params}。\n价格方面，官方发布价为2500美元，现在促销价为15699元人民币。\n用户
#   体验反馈如下：{nikon_z63_user_review}。"
#   print(nikon_z63_summary)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 尼康Z63具有以下参数：2450万像素BSI背照式CMOS, EXPEED 7影像处理器, 1/16000秒快门速度, 机械快门14fps/电子快门20fps,
# 293/297点自动对焦点, 6K 12bit NRAW无裁切, 4K 60P ProRes RAW, 五轴7级或8级机身防抖, 576万像素EVF, 支持FHD
# 240P高格率录制, 改良翻转屏, CFexpress + SD双卡槽, USB-C 3.0, HDMI A, 支持Z6 III的Nikon NX Studio新版本App。。
# 价格方面，官方发布价为2500美元，现在促销价为15699元人民币。
# 用户体验反馈如下：优点: 优秀的视频功能（6K 12bit NRAW无裁切, 4K 60P ProRes
# RAW），出色的低光画质表现，高动态范围，强的防抖性能。缺点: 电池续航一般，价格偏高。。
#
# Out: None
# [Step 2: Duration 19.81 seconds| Input tokens: 23,437 | Output tokens: 442]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer(nikon_z63_summary)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: 尼康Z63具有以下参数：2450万像素BSI背照式CMOS, EXPEED 7影像处理器, 1/16000秒快门速度,
# 机械快门14fps/电子快门20fps, 293/297点自动对焦点, 6K 12bit NRAW无裁切, 4K 60P ProRes RAW, 五轴7级或8级机身防抖,
# 576万像素EVF, 支持FHD 240P高格率录制, 改良翻转屏, CFexpress + SD双卡槽, USB-C 3.0, HDMI A, 支持Z6 III的Nikon NX
# Studio新版本App。。
# 价格方面，官方发布价为2500美元，现在促销价为15699元人民币。
# 用户体验反馈如下：优点: 优秀的视频功能（6K 12bit NRAW无裁切, 4K 60P ProRes
# RAW），出色的低光画质表现，高动态范围，强的防抖性能。缺点: 电池续航一般，价格偏高。。
# [Step 3: Duration 6.98 seconds| Input tokens: 45,836 | Output tokens: 494]
# '尼康Z63具有以下参数：2450万像素BSI背照式CMOS, EXPEED 7影像处理器, 1/16000秒快门速度, 机械快门14fps/电子快门20fps, 293/297点自动对焦点, 6K 12bit NRAW无裁切, 4K 60P ProRes RAW, 五轴7级或8级机身防抖, 576万像素EVF, 支持FHD 240P高格率录制, 改良翻转屏, CFexpress + SD双卡槽, USB-C 3.0, HDMI A, 支持Z6 III的Nikon NX Studio新版本App。。\n价格方面，官方发布价为2500美元，现在促销价为15699元人民币。\n用户体验反馈如下：优点: 优秀的视频功能（6K 12bit NRAW无裁切, 4K 60P ProRes RAW），出色的低光画质表现，高动态范围，强的防抖性能。缺点: 电池续航一般，价格偏高。。'
